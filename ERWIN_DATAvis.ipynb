# %%
import pandas as pd

df = pd.read_csv("data/Data 2022/Probes/Sonde Canon 1 one page.csv", sep=";")
df
# Out:
#             Date/heure Température de l'air MOY [°C]  \
# 0     08/09/2022 16:00                         22,05
# 1     08/09/2022 15:00                          20,9
# 2     08/09/2022 14:00                         20,92
# 3     08/09/2022 13:00                         20,15
# 4     08/09/2022 12:00                         19,09
# ...                ...                           ...
# 2347  02/06/2022 21:00                         18,35
# 2348  02/06/2022 20:00                          22,5
# 2349  02/06/2022 19:00                         23,71
# 2350  02/06/2022 18:00                         23,27
# 2351  02/06/2022 17:00                         23,68
#
#      Température de l'air MAX [°C] Température de l'air MIN [°C]  \
# 0                            22,69                         21,41
# 1                            21,32                         20,32
# 2                             21,4                         20,43
# 3                            20,75                         19,44
# 4                            19,62                         18,37
# ...                            ...                           ...
# 2347                         20,23                          15,6
# 2348                         24,42                         19,46
# 2349                         24,24                         23,16
# 2350                         23,72                         22,92
# 2351                         23,91                         23,41
#
#      Température sèche MOY [°C] Température sèche MAX [°C]  \
# 0                           NaN                        NaN
# 1                           NaN                        NaN
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                           NaN                        NaN
# ...                         ...                        ...
# 2347                        NaN                        NaN
# 2348                        NaN                        NaN
# 2349                        NaN                        NaN
# 2350                        NaN                        NaN
# 2351                        NaN                        NaN
#
#      Température sèche MIN [°C] Précipitations [mm] EAG Humidité du sol 1 [%]  \
# 0                           NaN                   0                         0
# 1                           NaN                   0                         0
# 2                           NaN                   0                         0
# 3                           NaN                   0                         0
# 4                           NaN                   0                         0
# ...                         ...                 ...                       ...
# 2347                        NaN                   0                         0
# 2348                        NaN                   0                         0
# 2349                        NaN                   0                         0
# 2350                        NaN                   0                         0
# 2351                        NaN                   0                         0
#
#      EAG Humidité du sol 2 [%]  ... Température du sol MAX 4 [°C]  \
# 0                            0  ...                          22,3
# 1                            0  ...                          21,3
# 2                            0  ...                          20,8
# 3                            0  ...                            20
# 4                            0  ...                            19
# ...                        ...  ...                           ...
# 2347                       1,1  ...                          18,2
# 2348                      1,05  ...                          17,9
# 2349                      1,04  ...                          17,6
# 2350                      1,03  ...                          17,6
# 2351                      0,99  ...                          22,5
#
#      Température du sol MIN 4 [°C] Température du sol MOY 5 [°C]  \
# 0                             21,5                          22,3
# 1                             20,4                          21,2
# 2                               20                          20,8
# 3                               19                          19,8
# 4                             17,9                          18,4
# ...                            ...                           ...
# 2347                          17,9                          16,6
# 2348                          17,6                          16,3
# 2349                          17,4                          16,2
# 2350                          17,4                          16,2
# 2351                          17,8                          18,2
#
#      Température du sol MAX 5 [°C] Température du sol MIN 5 [°C]  \
# 0                             22,7                          21,9
# 1                             21,8                          20,9
# 2                             21,3                          20,3
# 3                             20,3                          19,4
# 4                             19,3                          17,7
# ...                            ...                           ...
# 2347                          16,7                          16,5
# 2348                          16,5                          16,3
# 2349                          16,2                          16,1
# 2350                          16,5                          16,1
# 2351                          22,3                          16,7
#
#      Température du sol MOY 6 [°C] Température du sol MAX 6 [°C]  \
# 0                             22,6                          22,8
# 1                             21,5                          22,1
# 2                             20,9                          21,5
# 3                             20,1                          20,4
# 4                             18,7                          19,5
# ...                            ...                           ...
# 2347                            16                          16,1
# 2348                          15,9                          15,9
# 2349                          15,8                          15,8
# 2350                            16                          16,3
# 2351                          18,1                          22,6
#
#      Température du sol MIN 6 [°C] Panneau solaire [mV] Batterie [mV]
# 0                             22,2                    0          6459
# 1                               21                    0          6485
# 2                             20,4                    0          6499
# 3                             19,6                    0          6531
# 4                               18                    0          6610
# ...                            ...                  ...           ...
# 2347                          15,9                    0          6249
# 2348                          15,8                    0          6246
# 2349                          15,7                    0          6243
# 2350                          15,8                    0          6249
# 2351                          16,5                    0          6243
#
# [2352 rows x 34 columns]

# %%
df['Date/heure'] = pd.to_datetime(df['Date/heure'], format="%d/%m/%Y %H:%M")

# %%
df = df.sort_values(by='Date/heure').reset_index(drop=True)

# %%
df
# Out:
#               Date/heure Température de l'air MOY [°C]  \
# 0    2022-06-02 17:00:00                         23,68
# 1    2022-06-02 18:00:00                         23,27
# 2    2022-06-02 19:00:00                         23,71
# 3    2022-06-02 20:00:00                          22,5
# 4    2022-06-02 21:00:00                         18,35
# ...                  ...                           ...
# 2347 2022-09-08 12:00:00                         19,09
# 2348 2022-09-08 13:00:00                         20,15
# 2349 2022-09-08 14:00:00                         20,92
# 2350 2022-09-08 15:00:00                          20,9
# 2351 2022-09-08 16:00:00                         22,05
#
#      Température de l'air MAX [°C] Température de l'air MIN [°C]  \
# 0                            23,91                         23,41
# 1                            23,72                         22,92
# 2                            24,24                         23,16
# 3                            24,42                         19,46
# 4                            20,23                          15,6
# ...                            ...                           ...
# 2347                         19,62                         18,37
# 2348                         20,75                         19,44
# 2349                          21,4                         20,43
# 2350                         21,32                         20,32
# 2351                         22,69                         21,41
#
#      Température sèche MOY [°C] Température sèche MAX [°C]  \
# 0                           NaN                        NaN
# 1                           NaN                        NaN
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                           NaN                        NaN
# ...                         ...                        ...
# 2347                        NaN                        NaN
# 2348                        NaN                        NaN
# 2349                        NaN                        NaN
# 2350                        NaN                        NaN
# 2351                        NaN                        NaN
#
#      Température sèche MIN [°C] Précipitations [mm] EAG Humidité du sol 1 [%]  \
# 0                           NaN                   0                         0
# 1                           NaN                   0                         0
# 2                           NaN                   0                         0
# 3                           NaN                   0                         0
# 4                           NaN                   0                         0
# ...                         ...                 ...                       ...
# 2347                        NaN                   0                         0
# 2348                        NaN                   0                         0
# 2349                        NaN                   0                         0
# 2350                        NaN                   0                         0
# 2351                        NaN                   0                         0
#
#      EAG Humidité du sol 2 [%]  ... Température du sol MAX 4 [°C]  \
# 0                         0,99  ...                          22,5
# 1                         1,03  ...                          17,6
# 2                         1,04  ...                          17,6
# 3                         1,05  ...                          17,9
# 4                          1,1  ...                          18,2
# ...                        ...  ...                           ...
# 2347                         0  ...                            19
# 2348                         0  ...                            20
# 2349                         0  ...                          20,8
# 2350                         0  ...                          21,3
# 2351                         0  ...                          22,3
#
#      Température du sol MIN 4 [°C] Température du sol MOY 5 [°C]  \
# 0                             17,8                          18,2
# 1                             17,4                          16,2
# 2                             17,4                          16,2
# 3                             17,6                          16,3
# 4                             17,9                          16,6
# ...                            ...                           ...
# 2347                          17,9                          18,4
# 2348                            19                          19,8
# 2349                            20                          20,8
# 2350                          20,4                          21,2
# 2351                          21,5                          22,3
#
#      Température du sol MAX 5 [°C] Température du sol MIN 5 [°C]  \
# 0                             22,3                          16,7
# 1                             16,5                          16,1
# 2                             16,2                          16,1
# 3                             16,5                          16,3
# 4                             16,7                          16,5
# ...                            ...                           ...
# 2347                          19,3                          17,7
# 2348                          20,3                          19,4
# 2349                          21,3                          20,3
# 2350                          21,8                          20,9
# 2351                          22,7                          21,9
#
#      Température du sol MOY 6 [°C] Température du sol MAX 6 [°C]  \
# 0                             18,1                          22,6
# 1                               16                          16,3
# 2                             15,8                          15,8
# 3                             15,9                          15,9
# 4                               16                          16,1
# ...                            ...                           ...
# 2347                          18,7                          19,5
# 2348                          20,1                          20,4
# 2349                          20,9                          21,5
# 2350                          21,5                          22,1
# 2351                          22,6                          22,8
#
#      Température du sol MIN 6 [°C] Panneau solaire [mV] Batterie [mV]
# 0                             16,5                    0          6243
# 1                             15,8                    0          6249
# 2                             15,7                    0          6243
# 3                             15,8                    0          6246
# 4                             15,9                    0          6249
# ...                            ...                  ...           ...
# 2347                            18                    0          6610
# 2348                          19,6                    0          6531
# 2349                          20,4                    0          6499
# 2350                            21                    0          6485
# 2351                          22,2                    0          6459
#
# [2352 rows x 34 columns]

# %%
import missingno as msno 
  
msno.matrix(df)
# Out:
# <Axes: >

# %%
df['Date/heure'].diff().value_counts()
# Out:
# Date/heure
# 0 days 01:00:00    2351
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# Date/heure                       datetime64[ns]
# Température de l'air MOY [°C]            object
# Température de l'air MAX [°C]            object
# Température de l'air MIN [°C]            object
# Température sèche MOY [°C]               object
# Température sèche MAX [°C]               object
# Température sèche MIN [°C]               object
# Précipitations [mm]                      object
# EAG Humidité du sol 1 [%]                object
# EAG Humidité du sol 2 [%]                object
# EAG Humidité du sol 3 [%]                object
# EAG Humidité du sol 4 [%]                object
# EAG Humidité du sol 5 [%]                object
# EAG Humidité du sol 6 [%]                object
# Température du sol MOY 1 [°C]            object
# Température du sol MAX 1 [°C]            object
# Température du sol MIN 1 [°C]            object
# Température du sol MOY 2 [°C]            object
# Température du sol MAX 2 [°C]            object
# Température du sol MIN 2 [°C]            object
# Température du sol MOY 3 [°C]            object
# Température du sol MAX 3 [°C]            object
# Température du sol MIN 3 [°C]            object
# Température du sol MOY 4 [°C]            object
# Température du sol MAX 4 [°C]            object
# Température du sol MIN 4 [°C]            object
# Température du sol MOY 5 [°C]            object
# Température du sol MAX 5 [°C]            object
# Température du sol MIN 5 [°C]            object
# Température du sol MOY 6 [°C]            object
# Température du sol MAX 6 [°C]            object
# Température du sol MIN 6 [°C]            object
# Panneau solaire [mV]                      int64
# Batterie [mV]                             int64
# dtype: object

# %%
for column in df.columns:
    if column not in ['Date/heure', 'Batterie [mV]', 'Panneau solaire [mV]'] :
        print(column)
        df[column] = df[column].str.replace(',', '.').astype(float)
# Out:
# Température de l'air MOY [°C]
# Température de l'air MAX [°C]
# Température de l'air MIN [°C]
# Température sèche MOY [°C]
# Température sèche MAX [°C]
# Température sèche MIN [°C]
# Précipitations [mm]
# EAG Humidité du sol 1 [%]
# EAG Humidité du sol 2 [%]
# EAG Humidité du sol 3 [%]
# EAG Humidité du sol 4 [%]
# EAG Humidité du sol 5 [%]
# EAG Humidité du sol 6 [%]
# Température du sol MOY 1 [°C]
# Température du sol MAX 1 [°C]
# Température du sol MIN 1 [°C]
# Température du sol MOY 2 [°C]
# Température du sol MAX 2 [°C]
# Température du sol MIN 2 [°C]
# Température du sol MOY 3 [°C]
# Température du sol MAX 3 [°C]
# Température du sol MIN 3 [°C]
# Température du sol MOY 4 [°C]
# Température du sol MAX 4 [°C]
# Température du sol MIN 4 [°C]
# Température du sol MOY 5 [°C]
# Température du sol MAX 5 [°C]
# Température du sol MIN 5 [°C]
# Température du sol MOY 6 [°C]
# Température du sol MAX 6 [°C]
# Température du sol MIN 6 [°C]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

for i in range(1, 7):
    column_name = f'EAG Humidité du sol {i} [%]'
    plt.plot(df['Date/heure'],df[column_name], marker='.', label=column_name)
plt.title("EAG Humidité du sol [%]")
plt.xlabel('Date')
plt.legend()
plt.ylabel("EAG Humidité du sol [%]")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Date/heure'],df['Température de l\'air MAX [°C]'], label=column_name)
plt.title("Température de l'air MAX [°C]")
plt.xlabel('Date')
plt.legend()
plt.ylabel("Température de l'air MAX [°C]")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Date/heure'],df['Température de l\'air MAX [°C]'], label="Temp MAX")
plt.plot(df['Date/heure'],df['Température de l\'air MIN [°C]'], label="Temp MIN")
plt.title("Température de l'air MIN [°C]")
plt.xlabel('Date')
plt.legend()
plt.ylabel("Température de l'air MIN [°C]")
plt.grid(True)
plt.show()
